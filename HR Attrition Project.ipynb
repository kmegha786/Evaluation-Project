# %%
# Importing Required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\HRIDVI ARORA\Downloads\ibm-hr-analytics-employee-attrition-performance.zip")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# The dataset contains 1470 rows and 35 columns.

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# MonthlyIncome             1470.0   6502.931293  4707.956783  1009.0  2911.00
# MonthlyRate               1470.0  14313.103401  7117.786044  2094.0  8047.00
# NumCompaniesWorked        1470.0      2.693197     2.498009     0.0     1.00
# PercentSalaryHike         1470.0     15.209524     3.659938    11.0    12.00
# PerformanceRating         1470.0      3.153741     0.360824     3.0     3.00
# RelationshipSatisfaction  1470.0      2.712245     1.081209     1.0     2.00
# StandardHours             1470.0     80.000000     0.000000    80.0    80.00
# StockOptionLevel          1470.0      0.793878     0.852077     0.0     0.00
# TotalWorkingYears         1470.0     11.279592     7.780782     0.0     6.00
# TrainingTimesLastYear     1470.0      2.799320     1.289271     0.0     2.00
# WorkLifeBalance           1470.0      2.761224     0.706476     1.0     2.00
# YearsAtCompany            1470.0      7.008163     6.126525     0.0     3.00
# YearsInCurrentRole        1470.0      4.229252     3.623137     0.0     2.00
# YearsSinceLastPromotion   1470.0      2.187755     3.222430     0.0     0.00
# YearsWithCurrManager      1470.0      4.123129     3.568136     0.0     2.00
#
#                               50%       75%      max
# Age                          36.0     43.00     60.0
# DailyRate                   802.0   1157.00   1499.0
# DistanceFromHome              7.0     14.00     29.0
# Education                     3.0      4.00      5.0
# EmployeeCount                 1.0      1.00      1.0
# EmployeeNumber             1020.5   1555.75   2068.0
# EnvironmentSatisfaction       3.0      4.00      4.0
# HourlyRate                   66.0     83.75    100.0
# JobInvolvement                3.0      3.00      4.0
# JobLevel                      2.0      3.00      5.0
# JobSatisfaction               3.0      4.00      4.0
# MonthlyIncome              4919.0   8379.00  19999.0
# MonthlyRate               14235.5  20461.50  26999.0
# NumCompaniesWorked            2.0      4.00      9.0
# PercentSalaryHike            14.0     18.00     25.0
# PerformanceRating             3.0      3.00      4.0
# RelationshipSatisfaction      3.0      4.00      4.0
# StandardHours                80.0     80.00     80.0
# StockOptionLevel              1.0      1.00      3.0
# TotalWorkingYears            10.0     15.00     40.0
# TrainingTimesLastYear         3.0      3.00      6.0
# WorkLifeBalance               3.0      3.00      4.0
# YearsAtCompany                5.0      9.00     40.0
# YearsInCurrentRole            3.0      7.00     18.0
# YearsSinceLastPromotion       1.0      3.00     15.0
# YearsWithCurrManager          3.0      7.00     17.0

# %%
#Lets seperate Categorical and Continuous varibales.


#Checking for Categorical columns
Cat_col = []
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        Cat_col.append(i)
print(Cat_col)
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

# %%
# Checking for Continuous columns

num_col = []
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        num_col.append(i)
print(num_col)
# Out:
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(15,10))
ax=sns.countplot(x='Age',data=df)

# %%
plt.figure(figsize=(15,10))
ax=sns.countplot(x='DistanceFromHome',data=df)

# %%
plt.figure(figsize=(6,6))
sns.countplot(df['JobSatisfaction'])
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %% [markdown]
# It can be seen that majority of employees are satisfied with their job.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['TotalWorkingYears'])
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='count'>

# %% [markdown]
# Most of the employees have working experience between 6-10 years.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Education'])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# Most of the employees pursued level 3 education.

# %%
plt.figure(figsize=(8,6))
sns.countplot(df['MaritalStatus'])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# It can be seen that the employees are mostly married.

# %%
ax=sns.countplot(x='Attrition',data=df)
print(df['Attrition'].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# The observation depicts maximum no Attrition.

# %%
ax=sns.countplot(x='BusinessTravel',data=df)
print(df['BusinessTravel'].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# Majority of employees travel  rarely.

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
print(df['Department'].value_counts())
labels='Research & Development','Sales','Human Resources'
fig,ax = plt.subplots(figsize=(10,6))
ax.pie(df['Department'].value_counts(),labels=labels,autopct='%1.2f%%',shadow=True)
plt.show()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %% [markdown]
# Mostly, the employees are from Research and Development field.

# %%
plt.figure(figsize=(8,8))
ax=sns.countplot(x='EducationField',data=df,edgecolor="y",linewidth=3)
print(df['EducationField'].value_counts())
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [markdown]
# It is observed that majority of employees are from Life Science.

# %%
print(df['Gender'].value_counts())
labels='Male','Female'
fig,ax = plt.subplots(figsize=(10,6))
ax.pie(df['Gender'].value_counts(),labels=labels,autopct='%1.2f%%',shadow=True)
plt.show()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %% [markdown]
# Majority of the employees are male.

# %%
plt.figure(figsize=(10,9))
ax=sns.countplot(x='JobRole',data=df,edgecolor="m",linewidth=3)
plt.xticks(rotation=90)
print(df['JobRole'].value_counts())
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# It can be seen that most of the employees are Sales Executive while least belongs to Human Resources.

# %%
ax=sns.countplot(x='OverTime',data=df,linestyle="--",color='m',edgecolor="r",alpha=0.9,linewidth=3)
print(df['OverTime'].value_counts())
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# Majority of employees are not doing overtime.

# %%
df_cont=df[num_col]

# %%
df_cont.shape
# Out:
# (1470, 26)

# %%
plt.figure(figsize=(25,35),facecolor='yellow')
plotnumber=1

for column in df_cont:
    if plotnumber<=25:
        ax=plt.subplot(5,5,plotnumber)
        sns.distplot(df_cont[column])
        plt.xlabel(column,fontsize=15)
    plotnumber=plotnumber+1

plt.show()

# %% [markdown]
# From the above plot it can be concluded that none of the column follow normal distribution, almost all the columns is having skewness and needs to be removed later.

# %%
sns.scatterplot(df['MonthlyIncome'],df['TotalWorkingYears'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='TotalWorkingYears'>

# %% [markdown]
# It can be seen that total working years is directly proportional to the  monthly income.

# %%
sns.scatterplot(df['MonthlyIncome'],df['NumCompaniesWorked'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='NumCompaniesWorked'>

# %%
sns.scatterplot(x='MonthlyIncome',y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Attrition'>

# %%
plt.figure(figsize=(6,4))
plt.title("Comparison between Monthly Income and Education")
sns.barplot(df['Gender'],df['MonthlyIncome'],hue='Department',data = df)
plt.xlabel("Gender")
plt.ylabel("Monthly Income")
plt.show()

# %% [markdown]
# It can be seen that in Females, the  maximum income is from Human Resources Depatment and in males it is from Sales department.

# %%
plt.figure(figsize=(6,4))
plt.title("Comparison between Monthly Income and Gender")
sns.barplot(df['Gender'],df['MonthlyIncome'],hue='Attrition',data = df,color='green',edgecolor="r",alpha=0.9,linewidth=3)
plt.xlabel("Gender",fontsize=16)
plt.ylabel("Monthly Income",fontsize=16)
plt.show()

# %% [markdown]
# Attrition is less in both males and females.

# %%
plt.figure(figsize=(20,18))
plt.title("Comparison between Monthly Income and Jobrole")
sns.barplot(df['JobRole'],df['MonthlyIncome'],hue='Gender',data = df,color='yellow',edgecolor="m",linewidth=3)
plt.xlabel("JobRole",fontsize=18)
plt.ylabel("Monthly Income",fontsize=18)
plt.show()

# %% [markdown]
# # Now using encoder to encode the target variable

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
for i in Cat_col:
    df[i]=enc.fit_transform(df[i])

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0             2               1              1               1  ...
# 1             1               1              1               2  ...
# 2             2               4              1               4  ...
# 3             4               1              1               5  ...
# 4             1               3              1               7  ...
# ...         ...             ...            ...             ...  ...
# 1465          2               3              1            2061  ...
# 1466          1               3              1            2062  ...
# 1467          3               1              1            2064  ...
# 1468          3               3              1            2065  ...
# 1469          3               3              1            2068  ...
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                            1             80                 0
# 1                            4             80                 1
# 2                            2             80                 0
# 3                            3             80                 0
# 4                            4             80                 1
# ...                        ...            ...               ...
# 1465                         3             80                 1
# 1466                         1             80                 1
# 1467                         2             80                 1
# 1468                         4             80                 0
# 1469                         1             80                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 35 columns]

# %%
df.dtypes
# Out:
# Age                         int64
# Attrition                   int32
# BusinessTravel              int32
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int32
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# Over18                      int32
# OverTime                    int32
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# dtype: object

# %% [markdown]
# # Dropping Unnecessary columns.

# %%
df=df.drop(columns=['StandardHours','Over18','EmployeeCount'],axis=1)

# %% [markdown]
# # Checking for Corrrelation

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor='black',fmt='.2f')
plt.title("Correlation matrix")
plt.show()

# %% [markdown]
# Both positive and negative correlation with the target variable can be seen.

# %%
plt.figure(figsize=(20,18))
df.corr()['Attrition'].sort_values(ascending=False).drop(['Attrition']).plot(kind='bar',color='c',fontsize=15)
plt.xlabel('Features',fontsize=20)
plt.ylabel('Target',fontsize=20)
plt.title('Correlation between label and features using Bar plot',fontsize=18)
plt.show()

# %% [markdown]
# POSITIVELY CORRELATED COLUMN-: ['OverTime','Marital status','Distance from home','Job role,Department','Number of companies worked','Gender','Educationfeild','Monthly rate','Performance rating']
#
# NEGATIVELY CORRELATED COLUMN-:[Total working years , Job level,Years in current role , Monthly income , Age,Years with curr manager ,Stock option level,Years at company,job involment,job satisfaction,Environment satisfaction, Work life balance,Training time last year,Daily rate]

# %% [markdown]
# # Checking Skewess

# %%
df=df.drop(columns=['BusinessTravel','PerformanceRating'],axis=1)

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %% [markdown]
# Setting skewness limit to -0.65to +0.65

# %% [markdown]
# It can be observed that columns(Attrition, DistanceFrom Home, JobLevel, MonthlyIncome, NumCompaniesWorked, Overtime, PercentSalaryHike, StockOptionLevel, TotolWorkingYears, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager) are having skewness values above the limit

# %% [markdown]
# # Checking for Outliers

# %%
df.shape
# Out:
# (1470, 30)

# %%
plt.figure(figsize=(25,35),facecolor= 'red')
plotnumber = 1


for column in df:
    if plotnumber<=32:
        plt.subplot(6,6,plotnumber)
        ax=sns.boxplot(df[column],orient='v')
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# We can observe that the columns :- (TrainingTImesLastYear, YearsAtComapny,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager,
#  TotalWorkingYears,MOnthlyIncome,StockOptionLevel,NumComapniesWorked) are having outliers and needs to be removed.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Removing Outliers using Z-technique

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
z
# Out:
#            Age  Attrition  DailyRate  Department  DistanceFromHome  Education  \
# 0     0.446350   2.280906   0.742527    1.401512          1.010909   0.891688
# 1     1.322365   0.438422   1.297775    0.493817          0.147150   1.868426
# 2     0.008343   2.280906   1.414363    0.493817          0.887515   0.891688
# 3     0.429664   0.438422   1.461466    0.493817          0.764121   1.061787
# 4     1.086676   0.438422   0.524295    0.493817          0.887515   1.868426
# ...        ...        ...        ...         ...               ...        ...
# 1465  0.101159   0.438422   0.202082    0.493817          1.703764   0.891688
# 1466  0.227347   0.438422   0.469754    0.493817          0.393938   1.868426
# 1467  1.086676   0.438422   1.605183    0.493817          0.640727   0.085049
# 1468  1.322365   0.438422   0.546677    1.401512          0.887515   0.085049
# 1469  0.320163   0.438422   0.432568    0.493817          0.147150   0.085049
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction    Gender  ...  \
# 0           0.937414        1.701283                 0.660531  1.224745  ...
# 1           0.937414        1.699621                 0.254625  0.816497  ...
# 2           1.316673        1.696298                 1.169781  0.816497  ...
# 3           0.937414        1.694636                 1.169781  1.224745  ...
# 4           0.565311        1.691313                 1.575686  0.816497  ...
# ...              ...             ...                      ...       ...  ...
# 1465        0.565311        1.721670                 0.254625  0.816497  ...
# 1466        0.565311        1.723332                 1.169781  0.816497  ...
# 1467        0.937414        1.726655                 0.660531  0.816497  ...
# 1468        0.565311        1.728317                 1.169781  0.816497  ...
# 1469        0.565311        1.733302                 0.660531  0.816497  ...
#
#       PercentSalaryHike  RelationshipSatisfaction  StockOptionLevel  \
# 0              1.150554                  1.584178          0.932014
# 1              2.129306                  1.191438          0.241988
# 2              0.057267                  0.658973          0.932014
# 3              1.150554                  0.266233          0.932014
# 4              0.877232                  1.191438          0.241988
# ...                 ...                       ...               ...
# 1465           0.489376                  0.266233          0.241988
# 1466           0.057267                  1.584178          0.241988
# 1467           1.309341                  0.658973          0.241988
# 1468           0.330589                  1.191438          0.932014
# 1469           0.877232                  1.584178          0.932014
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0              0.421642               2.171982         2.493820
# 1              0.164511               0.155707         0.338096
# 2              0.550208               0.155707         0.338096
# 3              0.421642               0.155707         0.338096
# 4              0.678774               0.155707         0.338096
# ...                 ...                    ...              ...
# 1465           0.735447               0.155707         0.338096
# 1466           0.293077               1.707500         0.338096
# 1467           0.678774               2.171982         0.338096
# 1468           0.735447               0.155707         1.077862
# 1469           0.678774               0.155707         1.754054
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0           0.164613            0.063296                 0.679146
# 1           0.488508            0.764998                 0.368715
# 2           1.144294            1.167687                 0.679146
# 3           0.161947            0.764998                 0.252146
# 4           0.817734            0.615492                 0.058285
# ...              ...                 ...                      ...
# 1465        0.327893            0.615492                 0.679146
# 1466        0.001333            0.764998                 0.368715
# 1467        0.164613            0.615492                 0.679146
# 1468        0.325228            0.488900                 0.679146
# 1469        0.491174            0.339394                 0.368715
#
#       YearsWithCurrManager
# 0                 0.245834
# 1                 0.806541
# 2                 1.155935
# 3                 1.155935
# 4                 0.595227
# ...                    ...
# 1465              0.314873
# 1466              0.806541
# 1467              0.314873
# 1468              1.086895
# 1469              0.595227
#
# [1470 rows x 30 columns]

# %%
df_new=df[(z<3).all(axis=1)]
print("old dataframe",df.shape)
print("new dataframe",df_new.shape)
print("total number of rows dropped",df.shape[0]-df_new.shape[0])
# Out:
# old dataframe (1470, 30)
# new dataframe (1387, 30)
# total number of rows dropped 83

# %% [markdown]
# # Percentage data loss

# %%
loss_percent=(1470-1387)/1470*100
loss_percent
# Out:
# 5.646258503401361

# %% [markdown]
# The data loss is less than 10%.So,it is safe to remove outliers

# %% [markdown]
# # Separating features and target variable as x and y

# %%
x=df_new.drop(columns=['Attrition'],axis=1)
y=df_new['Attrition']

# %%
x.shape
# Out:
# (1387, 29)

# %%
y.shape
# Out:
# (1387,)

# %% [markdown]
# # FeatureSelection using Select Percentile Method

# %%
from sklearn.feature_selection import SelectPercentile,chi2

# %%
spercentile=SelectPercentile(score_func=chi2,percentile=80)
spercentile=spercentile.fit(x,y)
cols=spercentile.get_support(indices=True)

# %%
print('Feature index=',cols)
# Out:
# Feature index= [ 0  1  2  3  6  7 10 11 12 13 14 15 16 17 18 20 21 22 23 25 26 27 28]

# %%
features=x.columns[cols]   
print('Features=',list(features))
# Out:
# Features= ['Age', 'DailyRate', 'Department', 'DistanceFromHome', 'EmployeeNumber', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
df_scores=pd.DataFrame({'features':x.columns,'Chi2score':spercentile.scores_,'pvalue':spercentile.pvalues_})

# %%
df_scores.sort_values(by='Chi2score',ascending=False)
# Out:
#                     features      Chi2score         pvalue
# 15             MonthlyIncome  108739.104549   0.000000e+00
# 16               MonthlyRate    1066.236327  7.199964e-234
# 1                  DailyRate     915.089308  5.147740e-201
# 22         TotalWorkingYears     208.070075   3.621844e-47
# 25            YearsAtCompany     137.733136   8.335899e-32
# 26        YearsInCurrentRole     110.331536   8.289928e-26
# 28      YearsWithCurrManager     102.024111   5.485008e-24
# 0                        Age      75.845872   3.066929e-18
# 3           DistanceFromHome      66.101135   4.283689e-16
# 18                  OverTime      65.641342   5.409209e-16
# 6             EmployeeNumber      50.718371   1.066169e-12
# 21          StockOptionLevel      23.873727   1.028661e-06
# 11                  JobLevel      21.624943   3.315125e-06
# 14             MaritalStatus      17.292120   3.205133e-05
# 17        NumCompaniesWorked       8.191525   4.208653e-03
# 13           JobSatisfaction       7.994182   4.692790e-03
# 12                   JobRole       7.828838   5.141916e-03
# 7    EnvironmentSatisfaction       7.640280   5.707904e-03
# 10            JobInvolvement       4.577980   3.238538e-02
# 27   YearsSinceLastPromotion       4.175724   4.100703e-02
# 23     TrainingTimesLastYear       2.706628   9.993203e-02
# 20  RelationshipSatisfaction       1.642923   1.999248e-01
# 2                 Department       1.231681   2.670803e-01
# 24           WorkLifeBalance       0.973851   3.237215e-01
# 8                     Gender       0.725432   3.943678e-01
# 5             EducationField       0.609980   4.347955e-01
# 4                  Education       0.535825   4.641682e-01
# 19         PercentSalaryHike       0.047112   8.281670e-01
# 9                 HourlyRate       0.020329   8.866218e-01

# %%
x=df_new[['Age', 'DailyRate', 'Department', 'DistanceFromHome', 'EmployeeNumber', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']]

# %%
x.shape
# Out:
# (1387, 23)

# %%
y.shape
# Out:
# (1387,)

# %% [markdown]
# # Handling imbalanced dataset

# %% [markdown]
# Since target variable is imbalanced and size of dataset is small so we will do oversampling

# %% [markdown]
# # Over sampling using SMOTE

# %%
import sys
from collections import Counter
import joblib
import six
from sklearn.model_selection import train_test_split
sys.modules['sklearn.externals.six']=six
sys.modules['sklearn.externals.joblib']=joblib
from sklearn.model_selection import train_test_split

# %%
from imblearn.over_sampling import SMOTE

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.75,random_state=42)

# %%
over_smpl=SMOTE(sampling_strategy=0.75)
x_train_ns,y_train_ns=over_smpl.fit_resample(x_train,y_train)

# %%
print("The number of classes before fit{}".format(Counter(y_train)))
# Out:
# The number of classes before fitCounter({0: 282, 1: 64})

# %%
print("The number of classes after fit{}".format(Counter(y_train_ns)))
# Out:
# The number of classes after fitCounter({0: 282, 1: 211})

# %% [markdown]
# # Removing skewness using data transforamtion

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x,method='yeo-johnson')
x_new
# Out:
# array([[ 0.61013332,  0.75061538,  1.37988121, ...,  0.29052433,
#         -1.07353381,  0.58217664],
#        [ 1.37182973, -1.34337244, -0.4734996 , ...,  1.0065754 ,
#          0.19316755,  1.01807316],
#        [ 0.18248603,  1.33708042, -0.4734996 , ..., -1.57181404,
#         -1.07353381, -1.52842596],
#        ...,
#        [-1.0804891 , -1.75453754, -0.4734996 , ..., -0.39076907,
#         -1.07353381,  0.01867962],
#        [ 1.37182973,  0.57328582,  1.37988121, ...,  0.79376377,
#         -1.07353381,  1.20578193],
#        [-0.16377603, -0.37222758, -0.4734996 , ..., -0.01873824,
#          0.19316755, -0.3478709 ]])

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x
# Out:
#            Age  DailyRate  Department  DistanceFromHome  EmployeeNumber  \
# 0     0.610133   0.750615    1.379881         -1.489968       -2.167233
# 1     1.371830  -1.343372   -0.473500          0.244561       -2.157256
# 2     0.182486   1.337080   -0.473500         -1.028366       -2.139969
# 3    -0.284736   1.377080   -0.473500         -0.698191       -2.132165
# 4    -1.080489  -0.467301   -0.473500         -1.028366       -2.117665
# ...        ...        ...         ...               ...             ...
# 1382  0.069696   0.252885   -0.473500          1.408969        1.533695
# 1383  0.400794  -0.410602   -0.473500         -0.049519        1.534945
# 1384 -1.080489  -1.754538   -0.473500         -0.440553        1.537447
# 1385  1.371830   0.573286    1.379881         -1.028366        1.538697
# 1386 -0.163776  -0.372228   -0.473500          0.244561        1.542446
#
#       EnvironmentSatisfaction  JobInvolvement  JobLevel   JobRole  \
# 0                   -0.712215        0.322170  0.349828  1.017588
# 1                    0.204826       -1.065841  0.349828  0.596961
# 2                    1.210036       -1.065841 -1.141761 -1.022696
# 3                    1.210036        0.322170 -1.141761  0.596961
# 4                   -1.522916        0.322170 -1.141761 -1.022696
# ...                       ...             ...       ...       ...
# 1382                 0.204826        2.016459  0.349828 -1.022696
# 1383                 1.210036       -1.065841  1.133237 -1.768432
# 1384                -0.712215        2.016459  0.349828 -0.227587
# 1385                 1.210036       -1.065841  0.349828  1.017588
# 1386                -0.712215        2.016459  0.349828 -1.022696
#
#       JobSatisfaction  ...  NumCompaniesWorked  OverTime  \
# 0            1.186326  ...            1.620671  1.584737
# 1           -0.725589  ...           -0.561880 -0.631019
# 2            0.181993  ...            1.273711  1.584737
# 3            0.181993  ...           -0.561880  1.584737
# 4           -0.725589  ...            1.764103 -0.631019
# ...               ...  ...                 ...       ...
# 1382         1.186326  ...            0.798319 -0.631019
# 1383        -1.517783  ...            0.798319 -0.631019
# 1384        -0.725589  ...           -0.561880  1.584737
# 1385        -0.725589  ...            0.052119 -0.631019
# 1386         0.181993  ...            0.052119 -0.631019
#
#       RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                    -1.524369         -1.084263          -0.173231
# 1                     1.235448          0.548653           0.147620
# 2                    -0.690386         -1.084263          -0.351153
# 3                     0.235192         -1.084263          -0.173231
# 4                     1.235448          0.548653          -0.544046
# ...                        ...               ...                ...
# 1382                  0.235192          0.548653           1.039364
# 1383                 -1.524369          0.548653          -0.007630
# 1384                 -0.690386          0.548653          -0.544046
# 1385                  1.235448         -1.084263           1.039364
# 1386                 -1.524369         -1.084263          -0.544046
#
#       TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                 -2.608524        0.231837            0.290524
# 1                  0.217074        0.948319            1.006575
# 2                  0.217074       -2.156089           -1.571814
# 3                  0.217074        0.621429            1.006575
# 4                  0.217074       -0.933983           -0.390769
# ...                     ...             ...                 ...
# 1382               0.217074        0.003289           -0.390769
# 1383               1.606919        0.436162            1.006575
# 1384              -2.608524        0.231837           -0.390769
# 1385               0.217074        0.791264            0.793764
# 1386               0.217074       -0.257229           -0.018738
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                   -1.073534              0.582177
# 1                    0.193168              1.018073
# 2                   -1.073534             -1.528426
# 3                    1.027520             -1.528426
# 4                    0.722874             -0.347871
# ...                       ...                   ...
# 1382                -1.073534              0.018680
# 1383                 0.193168              1.018073
# 1384                -1.073534              0.018680
# 1385                -1.073534              1.205782
# 1386                 0.193168             -0.347871
#
# [1387 rows x 23 columns]

# %%
x.skew()
# Out:
# Age                        -0.004079
# DailyRate                  -0.199742
# Department                  0.015095
# DistanceFromHome           -0.008149
# EmployeeNumber             -0.287518
# EnvironmentSatisfaction    -0.205472
# JobInvolvement             -0.018801
# JobLevel                    0.110769
# JobRole                    -0.337641
# JobSatisfaction            -0.217730
# MaritalStatus              -0.158253
# MonthlyIncome               0.027700
# MonthlyRate                -0.176560
# NumCompaniesWorked          0.016175
# OverTime                    0.954751
# RelationshipSatisfaction   -0.191406
# StockOptionLevel            0.089929
# TotalWorkingYears          -0.009666
# TrainingTimesLastYear       0.057949
# YearsAtCompany             -0.025230
# YearsInCurrentRole         -0.069631
# YearsSinceLastPromotion     0.212301
# YearsWithCurrManager       -0.070570
# dtype: float64

# %% [markdown]
# We can observe that skewness has been removed.

# %%
plt.figure(figsize=(30,15),facecolor='yellow')
plotnumber=1

for column in x:
    if plotnumber<=23:
        ax=plt.subplot(4,6,plotnumber)
        sns.distplot(x[column])
    plotnumber=plotnumber+1

plt.show()

# %% [markdown]
# # Data Standardisation

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#            Age  DailyRate  Department  DistanceFromHome  EmployeeNumber  \
# 0     0.610133   0.750615    1.379881         -1.489968       -2.167233
# 1     1.371830  -1.343372   -0.473500          0.244561       -2.157256
# 2     0.182486   1.337080   -0.473500         -1.028366       -2.139969
# 3    -0.284736   1.377080   -0.473500         -0.698191       -2.132165
# 4    -1.080489  -0.467301   -0.473500         -1.028366       -2.117665
# ...        ...        ...         ...               ...             ...
# 1382  0.069696   0.252885   -0.473500          1.408969        1.533695
# 1383  0.400794  -0.410602   -0.473500         -0.049519        1.534945
# 1384 -1.080489  -1.754538   -0.473500         -0.440553        1.537447
# 1385  1.371830   0.573286    1.379881         -1.028366        1.538697
# 1386 -0.163776  -0.372228   -0.473500          0.244561        1.542446
#
#       EnvironmentSatisfaction  JobInvolvement  JobLevel   JobRole  \
# 0                   -0.712215        0.322170  0.349828  1.017588
# 1                    0.204826       -1.065841  0.349828  0.596961
# 2                    1.210036       -1.065841 -1.141761 -1.022696
# 3                    1.210036        0.322170 -1.141761  0.596961
# 4                   -1.522916        0.322170 -1.141761 -1.022696
# ...                       ...             ...       ...       ...
# 1382                 0.204826        2.016459  0.349828 -1.022696
# 1383                 1.210036       -1.065841  1.133237 -1.768432
# 1384                -0.712215        2.016459  0.349828 -0.227587
# 1385                 1.210036       -1.065841  0.349828  1.017588
# 1386                -0.712215        2.016459  0.349828 -1.022696
#
#       JobSatisfaction  ...  NumCompaniesWorked  OverTime  \
# 0            1.186326  ...            1.620671  1.584737
# 1           -0.725589  ...           -0.561880 -0.631019
# 2            0.181993  ...            1.273711  1.584737
# 3            0.181993  ...           -0.561880  1.584737
# 4           -0.725589  ...            1.764103 -0.631019
# ...               ...  ...                 ...       ...
# 1382         1.186326  ...            0.798319 -0.631019
# 1383        -1.517783  ...            0.798319 -0.631019
# 1384        -0.725589  ...           -0.561880  1.584737
# 1385        -0.725589  ...            0.052119 -0.631019
# 1386         0.181993  ...            0.052119 -0.631019
#
#       RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                    -1.524369         -1.084263          -0.173231
# 1                     1.235448          0.548653           0.147620
# 2                    -0.690386         -1.084263          -0.351153
# 3                     0.235192         -1.084263          -0.173231
# 4                     1.235448          0.548653          -0.544046
# ...                        ...               ...                ...
# 1382                  0.235192          0.548653           1.039364
# 1383                 -1.524369          0.548653          -0.007630
# 1384                 -0.690386          0.548653          -0.544046
# 1385                  1.235448         -1.084263           1.039364
# 1386                 -1.524369         -1.084263          -0.544046
#
#       TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                 -2.608524        0.231837            0.290524
# 1                  0.217074        0.948319            1.006575
# 2                  0.217074       -2.156089           -1.571814
# 3                  0.217074        0.621429            1.006575
# 4                  0.217074       -0.933983           -0.390769
# ...                     ...             ...                 ...
# 1382               0.217074        0.003289           -0.390769
# 1383               1.606919        0.436162            1.006575
# 1384              -2.608524        0.231837           -0.390769
# 1385               0.217074        0.791264            0.793764
# 1386               0.217074       -0.257229           -0.018738
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                   -1.073534              0.582177
# 1                    0.193168              1.018073
# 2                   -1.073534             -1.528426
# 3                    1.027520             -1.528426
# 4                    0.722874             -0.347871
# ...                       ...                   ...
# 1382                -1.073534              0.018680
# 1383                 0.193168              1.018073
# 1384                -1.073534              0.018680
# 1385                -1.073534              1.205782
# 1386                 0.193168             -0.347871
#
# [1387 rows x 23 columns]

# %% [markdown]
# # Check for multicollierinity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['vif1']=[variance_inflation_factor(x,i) for i in range(x.shape[1])]
vif['features']=x.columns
vif
# Out:
#         vif1                  features
# 0   1.879790                       Age
# 1   1.021725                 DailyRate
# 2   2.151713                Department
# 3   1.014927          DistanceFromHome
# 4   1.020216            EmployeeNumber
# 5   1.018162   EnvironmentSatisfaction
# 6   1.015591            JobInvolvement
# 7   5.914184                  JobLevel
# 8   2.011914                   JobRole
# 9   1.014935           JobSatisfaction
# 10  2.285936             MaritalStatus
# 11  5.816364             MonthlyIncome
# 12  1.018217               MonthlyRate
# 13  1.417758        NumCompaniesWorked
# 14  1.023675                  OverTime
# 15  1.020929  RelationshipSatisfaction
# 16  2.276977          StockOptionLevel
# 17  4.079931         TotalWorkingYears
# 18  1.019449     TrainingTimesLastYear
# 19  6.267598            YearsAtCompany
# 20  3.497541        YearsInCurrentRole
# 21  1.366159   YearsSinceLastPromotion
# 22  3.421189      YearsWithCurrManager

# %%
x=x.drop(columns=['YearsAtCompany'],axis=1)

# %%
vif=pd.DataFrame()
vif['vif1']=[variance_inflation_factor(x,i) for i in range(x.shape[1])]
vif['features']=x.columns
vif
# Out:
#         vif1                  features
# 0   1.876780                       Age
# 1   1.021016                 DailyRate
# 2   2.150989                Department
# 3   1.014851          DistanceFromHome
# 4   1.018151            EmployeeNumber
# 5   1.018153   EnvironmentSatisfaction
# 6   1.015116            JobInvolvement
# 7   5.907808                  JobLevel
# 8   2.011410                   JobRole
# 9   1.013089           JobSatisfaction
# 10  2.283349             MaritalStatus
# 11  5.816181             MonthlyIncome
# 12  1.016300               MonthlyRate
# 13  1.325366        NumCompaniesWorked
# 14  1.023354                  OverTime
# 15  1.020875  RelationshipSatisfaction
# 16  2.275880          StockOptionLevel
# 17  3.809221         TotalWorkingYears
# 18  1.019413     TrainingTimesLastYear
# 19  2.415177        YearsInCurrentRole
# 20  1.359277   YearsSinceLastPromotion
# 21  2.403014      YearsWithCurrManager

# %%
x=x.drop(columns=['JobLevel'],axis=1)

# %%
vif=pd.DataFrame()
vif['vif1']=[variance_inflation_factor(x,i) for i in range(x.shape[1])]
vif['features']=x.columns
vif
# Out:
#         vif1                  features
# 0   1.876600                       Age
# 1   1.019865                 DailyRate
# 2   2.058919                Department
# 3   1.012096          DistanceFromHome
# 4   1.018094            EmployeeNumber
# 5   1.014573   EnvironmentSatisfaction
# 6   1.015106            JobInvolvement
# 7   1.989514                   JobRole
# 8   1.013016           JobSatisfaction
# 9   2.282843             MaritalStatus
# 10  2.239797             MonthlyIncome
# 11  1.015173               MonthlyRate
# 12  1.321299        NumCompaniesWorked
# 13  1.022670                  OverTime
# 14  1.019936  RelationshipSatisfaction
# 15  2.275767          StockOptionLevel
# 16  3.658143         TotalWorkingYears
# 17  1.018244     TrainingTimesLastYear
# 18  2.410264        YearsInCurrentRole
# 19  1.359256   YearsSinceLastPromotion
# 20  2.402092      YearsWithCurrManager

# %% [markdown]
# We can observe that multicollinearity is removed .VIF value is less than 5 for all features.

# %% [markdown]
# # Model Training and Building

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,roc_auc_score,roc_curve

# %% [markdown]
# # Finding the best random state

# %%
max_acc=0
max_rs=0

for i in range(0,200):
    x_train_ns,x_test,y_train_ns,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    rf=RandomForestClassifier()
    rf.fit(x_train_ns,y_train_ns)
    pred_rf=rf.predict(x_test)
    accuracy=accuracy_score(y_test,pred_rf)
    print('Testing accuracy', accuracy,'random state',i)
    
    if accuracy>max_acc:
        max_acc=accuracy
        max_rs=i
        print('max_accuracy',max_acc,'max_random_state',i)
# Out:
# Testing accuracy 0.8669064748201439 random state 0
# max_accuracy 0.8669064748201439 max_random_state 0
# Testing accuracy 0.8453237410071942 random state 1
# Testing accuracy 0.8669064748201439 random state 2
# Testing accuracy 0.8705035971223022 random state 3
# max_accuracy 0.8705035971223022 max_random_state 3
# Testing accuracy 0.8525179856115108 random state 4
# Testing accuracy 0.841726618705036 random state 5
# Testing accuracy 0.9028776978417267 random state 6
# max_accuracy 0.9028776978417267 max_random_state 6
# Testing accuracy 0.8669064748201439 random state 7
# Testing accuracy 0.8705035971223022 random state 8
# Testing accuracy 0.8381294964028777 random state 9
# Testing accuracy 0.8381294964028777 random state 10
# Testing accuracy 0.8633093525179856 random state 11
# Testing accuracy 0.8165467625899281 random state 12
# Testing accuracy 0.8561151079136691 random state 13
# Testing accuracy 0.8237410071942446 random state 14
# Testing accuracy 0.8453237410071942 random state 15
# Testing accuracy 0.841726618705036 random state 16
# Testing accuracy 0.8489208633093526 random state 17
# Testing accuracy 0.8381294964028777 random state 18
# Testing accuracy 0.8597122302158273 random state 19
# Testing accuracy 0.8525179856115108 random state 20
# Testing accuracy 0.8309352517985612 random state 21
# Testing accuracy 0.8381294964028777 random state 22
# Testing accuracy 0.8309352517985612 random state 23
# Testing accuracy 0.8309352517985612 random state 24
# Testing accuracy 0.8812949640287769 random state 25
# Testing accuracy 0.8453237410071942 random state 26
# Testing accuracy 0.8201438848920863 random state 27
# Testing accuracy 0.8309352517985612 random state 28
# Testing accuracy 0.8309352517985612 random state 29
# Testing accuracy 0.8884892086330936 random state 30
# Testing accuracy 0.8345323741007195 random state 31
# Testing accuracy 0.8741007194244604 random state 32
# Testing accuracy 0.8525179856115108 random state 33
# Testing accuracy 0.8273381294964028 random state 34
# Testing accuracy 0.8525179856115108 random state 35
# Testing accuracy 0.841726618705036 random state 36
# Testing accuracy 0.8453237410071942 random state 37
# Testing accuracy 0.8237410071942446 random state 38
# Testing accuracy 0.8345323741007195 random state 39
# Testing accuracy 0.8309352517985612 random state 40
# Testing accuracy 0.8309352517985612 random state 41
# Testing accuracy 0.8237410071942446 random state 42
# Testing accuracy 0.8561151079136691 random state 43
# Testing accuracy 0.8669064748201439 random state 44
# Testing accuracy 0.8812949640287769 random state 45
# Testing accuracy 0.8381294964028777 random state 46
# Testing accuracy 0.8453237410071942 random state 47
# Testing accuracy 0.8884892086330936 random state 48
# Testing accuracy 0.8525179856115108 random state 49
# Testing accuracy 0.8597122302158273 random state 50
# Testing accuracy 0.8705035971223022 random state 51
# Testing accuracy 0.8345323741007195 random state 52
# Testing accuracy 0.8237410071942446 random state 53
# Testing accuracy 0.8489208633093526 random state 54
# Testing accuracy 0.8705035971223022 random state 55
# Testing accuracy 0.8920863309352518 random state 56
# Testing accuracy 0.8705035971223022 random state 57
# Testing accuracy 0.8705035971223022 random state 58
# Testing accuracy 0.8201438848920863 random state 59
# Testing accuracy 0.8273381294964028 random state 60
# Testing accuracy 0.8381294964028777 random state 61
# Testing accuracy 0.8705035971223022 random state 62
# Testing accuracy 0.8812949640287769 random state 63
# Testing accuracy 0.8489208633093526 random state 64
# Testing accuracy 0.8309352517985612 random state 65
# Testing accuracy 0.841726618705036 random state 66
# Testing accuracy 0.8669064748201439 random state 67
# Testing accuracy 0.8453237410071942 random state 68
# Testing accuracy 0.8884892086330936 random state 69
# Testing accuracy 0.8561151079136691 random state 70
# Testing accuracy 0.8525179856115108 random state 71
# Testing accuracy 0.8705035971223022 random state 72
# Testing accuracy 0.8705035971223022 random state 73
# Testing accuracy 0.8345323741007195 random state 74
# Testing accuracy 0.8345323741007195 random state 75
# Testing accuracy 0.8776978417266187 random state 76
# Testing accuracy 0.8776978417266187 random state 77
# Testing accuracy 0.8597122302158273 random state 78
# Testing accuracy 0.8561151079136691 random state 79
# Testing accuracy 0.8776978417266187 random state 80
# Testing accuracy 0.8812949640287769 random state 81
# Testing accuracy 0.8597122302158273 random state 82
# Testing accuracy 0.8561151079136691 random state 83
# Testing accuracy 0.8561151079136691 random state 84
# Testing accuracy 0.8489208633093526 random state 85
# Testing accuracy 0.8489208633093526 random state 86
# Testing accuracy 0.8525179856115108 random state 87
# Testing accuracy 0.8201438848920863 random state 88
# Testing accuracy 0.8705035971223022 random state 89
# Testing accuracy 0.8705035971223022 random state 90
# Testing accuracy 0.8812949640287769 random state 91
# Testing accuracy 0.8812949640287769 random state 92
# Testing accuracy 0.8597122302158273 random state 93
# Testing accuracy 0.8453237410071942 random state 94
# Testing accuracy 0.8525179856115108 random state 95
# Testing accuracy 0.8273381294964028 random state 96
# Testing accuracy 0.8453237410071942 random state 97
# Testing accuracy 0.8345323741007195 random state 98
# Testing accuracy 0.8776978417266187 random state 99
# Testing accuracy 0.8381294964028777 random state 100
# Testing accuracy 0.8597122302158273 random state 101
# Testing accuracy 0.8057553956834532 random state 102
# Testing accuracy 0.8309352517985612 random state 103
# Testing accuracy 0.8237410071942446 random state 104
# Testing accuracy 0.8453237410071942 random state 105
# Testing accuracy 0.9028776978417267 random state 106
# Testing accuracy 0.8633093525179856 random state 107
# Testing accuracy 0.8093525179856115 random state 108
# Testing accuracy 0.8992805755395683 random state 109
# Testing accuracy 0.8273381294964028 random state 110
# Testing accuracy 0.8669064748201439 random state 111
# Testing accuracy 0.8453237410071942 random state 112
# Testing accuracy 0.8453237410071942 random state 113
# Testing accuracy 0.89568345323741 random state 114
# Testing accuracy 0.8741007194244604 random state 115
# Testing accuracy 0.8309352517985612 random state 116
# Testing accuracy 0.8741007194244604 random state 117
# Testing accuracy 0.841726618705036 random state 118
# Testing accuracy 0.8741007194244604 random state 119
# Testing accuracy 0.8561151079136691 random state 120
# Testing accuracy 0.8597122302158273 random state 121
# Testing accuracy 0.841726618705036 random state 122
# Testing accuracy 0.8705035971223022 random state 123
# Testing accuracy 0.8489208633093526 random state 124
# Testing accuracy 0.8561151079136691 random state 125
# Testing accuracy 0.8992805755395683 random state 126
# Testing accuracy 0.8597122302158273 random state 127
# Testing accuracy 0.8093525179856115 random state 128
# Testing accuracy 0.8453237410071942 random state 129
# Testing accuracy 0.8453237410071942 random state 130
# Testing accuracy 0.8165467625899281 random state 131
# Testing accuracy 0.8273381294964028 random state 132
# Testing accuracy 0.8489208633093526 random state 133
# Testing accuracy 0.8561151079136691 random state 134
# Testing accuracy 0.8848920863309353 random state 135
# Testing accuracy 0.8705035971223022 random state 136
# Testing accuracy 0.8309352517985612 random state 137
# Testing accuracy 0.8381294964028777 random state 138
# Testing accuracy 0.8489208633093526 random state 139
# Testing accuracy 0.8345323741007195 random state 140
# Testing accuracy 0.8489208633093526 random state 141
# Testing accuracy 0.8057553956834532 random state 142
# Testing accuracy 0.8489208633093526 random state 143
# Testing accuracy 0.8381294964028777 random state 144
# Testing accuracy 0.8489208633093526 random state 145
# Testing accuracy 0.8561151079136691 random state 146
# Testing accuracy 0.8453237410071942 random state 147
# Testing accuracy 0.8669064748201439 random state 148
# Testing accuracy 0.8489208633093526 random state 149
# Testing accuracy 0.8525179856115108 random state 150
# Testing accuracy 0.841726618705036 random state 151
# Testing accuracy 0.8741007194244604 random state 152
# Testing accuracy 0.8669064748201439 random state 153
# Testing accuracy 0.8633093525179856 random state 154
# Testing accuracy 0.8561151079136691 random state 155
# Testing accuracy 0.8525179856115108 random state 156
# Testing accuracy 0.8561151079136691 random state 157
# Testing accuracy 0.8776978417266187 random state 158
# Testing accuracy 0.8669064748201439 random state 159
# Testing accuracy 0.8453237410071942 random state 160
# Testing accuracy 0.8453237410071942 random state 161
# Testing accuracy 0.8201438848920863 random state 162
# Testing accuracy 0.8705035971223022 random state 163
# Testing accuracy 0.8920863309352518 random state 164
# Testing accuracy 0.8237410071942446 random state 165
# Testing accuracy 0.8812949640287769 random state 166
# Testing accuracy 0.8165467625899281 random state 167
# Testing accuracy 0.8525179856115108 random state 168
# Testing accuracy 0.8165467625899281 random state 169
# Testing accuracy 0.9028776978417267 random state 170
# Testing accuracy 0.8561151079136691 random state 171
# Testing accuracy 0.8705035971223022 random state 172
# Testing accuracy 0.8273381294964028 random state 173
# Testing accuracy 0.8201438848920863 random state 174
# Testing accuracy 0.8741007194244604 random state 175
# Testing accuracy 0.8884892086330936 random state 176
# Testing accuracy 0.8633093525179856 random state 177
# Testing accuracy 0.8633093525179856 random state 178
# Testing accuracy 0.8669064748201439 random state 179
# Testing accuracy 0.8992805755395683 random state 180
# Testing accuracy 0.8633093525179856 random state 181
# Testing accuracy 0.8633093525179856 random state 182
# Testing accuracy 0.8273381294964028 random state 183
# Testing accuracy 0.8561151079136691 random state 184
# Testing accuracy 0.8489208633093526 random state 185
# Testing accuracy 0.8561151079136691 random state 186
# Testing accuracy 0.8561151079136691 random state 187
# Testing accuracy 0.8489208633093526 random state 188
# Testing accuracy 0.8597122302158273 random state 189
# Testing accuracy 0.8453237410071942 random state 190
# Testing accuracy 0.8561151079136691 random state 191
# Testing accuracy 0.8561151079136691 random state 192
# Testing accuracy 0.8633093525179856 random state 193
# Testing accuracy 0.8525179856115108 random state 194
# Testing accuracy 0.8812949640287769 random state 195
# Testing accuracy 0.8345323741007195 random state 196
# Testing accuracy 0.8453237410071942 random state 197
# Testing accuracy 0.8345323741007195 random state 198
# Testing accuracy 0.8669064748201439 random state 199

# %% [markdown]
# We are getting higest testing aacuracy at random state of 126

# %%
x_train_ns,x_test,y_train_ns,y_test=train_test_split(x,y,random_state=126,test_size=0.20)

# %%
def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train_ns)
        print(f"Accuracy score in training:{accuracy_score(y_train_ns,y_pred)*100:2f}%")
        
    elif train==False:
        pred=clf.predict(x_test)
        print(f"Accuracy score in testing:{accuracy_score(y_test,pred)*100:2f}%")
        
        print("Classification report\n",classification_report(y_test,pred,digits=2))

# %%
rf.fit(x_train_ns,y_train_ns)
# Out:
# RandomForestClassifier()

# %%
metric_score(rf,x_train_ns,x_test,y_train_ns,y_test,train=True)
# Out:
# Accuracy score in training:100.000000%

# %%
metric_score(rf,x_train_ns,x_test,y_train_ns,y_test,train=False)
# Out:
# Accuracy score in testing:89.568345%
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       245
#            1       0.67      0.24      0.36        33
#
#     accuracy                           0.90       278
#    macro avg       0.79      0.61      0.65       278
# weighted avg       0.88      0.90      0.87       278

# %% [markdown]
# # Finding best Cross Validation score for Logistic Regression:

# %%
pred_rf=rf.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_rf)
for j in range(2,10):
    cv_score=cross_val_score(rf,x,y,cv=j)
    cv_score_mean=cv_score.mean()
    print("cv at ", j)
    print("Cross validation score is :-", cv_score_mean*100)
    print()
# Out:
# cv at  2
# Cross validation score is :- 85.5799659834242
#
# cv at  3
# Cross validation score is :- 85.65257636531936
#
# cv at  4
# Cross validation score is :- 85.65178824274125
#
# cv at  5
# Cross validation score is :- 85.43594005661896
#
# cv at  6
# Cross validation score is :- 84.85999154102602
#
# cv at  7
# Cross validation score is :- 85.50907495631114
#
# cv at  8
# Cross validation score is :- 85.50885323234337
#
# cv at  9
# Cross validation score is :- 85.50807615323744

# %% [markdown]
# We are getting least difference between testing accuracy and cross val score at cv=9.

# %% [markdown]
# # Cross Validation Score

# %%
lssscore_selected=cross_val_score(rf,x,y,cv=9).mean()
print("the cv score is ",lssscore_selected)
# Out:
# the cv score is  0.857240608853512

# %% [markdown]
# # Support Vector Machine(SVM)

# %%
from sklearn.svm import SVC

# %%
svm=SVC()

# %%
svm.fit(x_train_ns,y_train_ns)
# Out:
# SVC()

# %%
metric_score(svm,x_train_ns,x_test,y_train_ns,y_test,train=True)
# Out:
# Accuracy score in training:91.253381%

# %%
metric_score(svm,x_train_ns,x_test,y_train_ns,y_test,train=False)
# Out:
# Accuracy score in testing:90.647482%
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       245
#            1       0.67      0.42      0.52        33
#
#     accuracy                           0.91       278
#    macro avg       0.80      0.70      0.73       278
# weighted avg       0.90      0.91      0.90       278

# %% [markdown]
# # Cross Validation Score

# %%
v_score=cross_val_score(svm,x,y,cv=9).mean()
print("the cv score is ",cv_score)
# Out:
# the cv score is  [0.85806452 0.84415584 0.86363636 0.85064935 0.87012987 0.83116883
#  0.85064935 0.87012987 0.85714286]

# %% [markdown]
# # Decison Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train_ns,y_train_ns)
# Out:
# DecisionTreeClassifier()

# %%
metric_score(dt,x_train_ns,x_test,y_train_ns,y_test,train=True)
# Out:
# Accuracy score in training:100.000000%

# %%
metric_score(dt,x_train_ns,x_test,y_train_ns,y_test,train=False)
# Out:
# Accuracy score in testing:78.417266%
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       245
#            1       0.25      0.42      0.32        33
#
#     accuracy                           0.78       278
#    macro avg       0.58      0.63      0.59       278
# weighted avg       0.84      0.78      0.81       278

# %% [markdown]
# # Cross Validation Score

# %%
cv_score=cross_val_score(dt,x,y,cv=9).mean()
print("the cv score is ",cv_score)
# Out:
# the cv score is  0.7815435460596751

# %% [markdown]
# # Gradient Boosting Tree

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbt=GradientBoostingClassifier()

# %%
gbt.fit(x_train_ns,y_train_ns)
# Out:
# GradientBoostingClassifier()

# %%
metric_score(gbt,x_train_ns,x_test,y_train_ns,y_test,train=True)
# Out:
# Accuracy score in training:94.048693%

# %%
metric_score(gbt,x_train_ns,x_test,y_train_ns,y_test,train=False)
# Out:
# Accuracy score in testing:89.208633%
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       245
#            1       0.57      0.36      0.44        33
#
#     accuracy                           0.89       278
#    macro avg       0.74      0.66      0.69       278
# weighted avg       0.88      0.89      0.88       278

# %% [markdown]
# # Cross Validation score

# %%
cv_score=cross_val_score(gbt,x,y,cv=9).mean()
print("the cv score is ",cv_score)
# Out:
# the cv score is  0.8558162267839687

# %% [markdown]
# # Conclusion

# %% [markdown]
# We can observe that at random state 126 and cv=9
#
# SVM
#
# ------Testing Accuracy:90.64 and Cross val score:86.58--------
#
# Random Forest
#
# ------Testing Accuracy:89.92 and Cross val score:85.29--------
#
# Decision Tree
#
# ------Testing Accuracy:80.57 and Cross val score:78.51--------
#
# Gradient Boosting Trees
#
# ------ Testing Accuracy:89.56 and Cross val score:85.79--------

# %% [markdown]
# # Plotting auc for all models

# %%
from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve


disp=plot_roc_curve(rf,x_train_ns,y_train_ns)
plot_roc_curve(dt,x_train_ns,y_train_ns,ax=disp.ax_)
plot_roc_curve(gbt,x_train_ns,y_train_ns,ax=disp.ax_)
plot_roc_curve(svm,x_train_ns,y_train_ns,ax=disp.ax_)
plt.legend(prop={'size':10},loc='lower right')
plt.plot([0,1],[0,1],color='navy',lw=5,linestyle='--')
plt.title('Recieving operating characterstics')
# Out:
# Text(0.5, 1.0, 'Recieving operating characterstics')

# %% [markdown]
# We can conclude Random Forest is the best model for this dataset as it has maximum AUC Score and testing accuracy
